# %%
import pandas as pd 
import os

# %%
cities_df = pd.read_csv('cities-Copy1.csv')

cities_df.head()
# Out:
#    Unnamed: 0            City  Latitude  Longitude  Max Temperature  Humidity  \
# 0           0  ribeira grande     38.52     -28.70            58.71        79
# 1           1         kirensk     57.79     108.11            13.48        93
# 2           2         ushuaia    -54.80     -68.30            42.80        75
# 3           3       busselton    -33.65     115.33            60.01        89
# 4           4       tocopilla    -22.09     -70.20            66.18        62
#
#    Clouds   Wind Country        Date
# 0      44  18.72      PT  1607037274
# 1     100   9.51      RU  1607037275
# 2      75  23.04      AR  1607037114
# 3      36  11.72      AU  1607037275
# 4      21   5.64      CL  1607037275

# %%
table = cities_df.to_html()
table
# Out:
# d>\n      <td>94</td>\n      <td>40</td>\n      <td>7.72</td>\n      <td>DO</td>\n      <td>1607037352</td>\n    </tr>\n    <tr>\n      <th>479</th>\n      <td>479</td>\n      <td>bambanglipuro</td>\n      <td>-7.95</td>\n      <td>110.28</td>\n      <td>78.84</td>\n      <td>80</td>\n      <td>87</td>\n      <td>3.80</td>\n      <td>ID</td>\n      <td>1607037352</td>\n    </tr>\n    <tr>\n      <th>480</th>\n      <td>480</td>\n      <td>varzea da palma</td>\n      <td>-17.60</td>\n      <td>-44.73</td>\n      <td>75.11</td>\n      <td>76</td>\n      <td>100</td>\n      <td>1.61</td>\n      <td>BR</td>\n      <td>1607037352</td>\n    </tr>\n    <tr>\n      <th>481</th>\n      <td>481</td>\n      <td>aswan</td>\n      <td>24.09</td>\n      <td>32.91</td>\n      <td>59.67</td>\n      <td>40</td>\n      <td>0</td>\n      <td>7.38</td>\n      <td>EG</td>\n      <td>1607037352</td>\n    </tr>\n    <tr>\n      <th>482</th>\n      <td>482</td>\n      <td>dongsheng</td>\n      <td>39.82</td
# ...

# %%
cities_df.to_html('cities.html')
